# %% [markdown]
# # 14 – ETL de FAOSTAT: Cost and Affordability of a Healthy Diet (UE-27, 2017–2023)
#
# En este notebook se transforma el fichero CSV descargado de FAOSTAT:
#
# `data_raw/faostat/FAOSTAT_data_en_12-9-2025.csv`
#
# El fichero pertenece al dominio:
#
# - CAHD – Cost and Affordability of a Healthy Diet (CoAHD)
#
# y contiene, para cada país y año, distintos indicadores relacionados con:
#
# - Cost of a healthy diet (CoHD), LCU per person per day.
# - Otros indicadores derivados del coste y asequibilidad.
#
# ### Objetivos del ETL
#
# Generar un dataset limpio y en formato columnar (Parquet) que:
#
# - Esté filtrado a:
#
#   - Países de la Unión Europea.
#   - Años 2017–2023 (intersección útil con el resto de fuentes).
#
# - Mantenga la estructura típica de FAOSTAT:
#
#   - País / área (`Area`, código M49).
#   - Indicador (`Item`).
#   - Año (`Year`).
#   - Unidad (`Unit`).
#   - Valor numérico (`Value`).
#
# - Añada un código de país compatible con Eurostat / OFF:
#
#   - `geo`: código ISO2 tipo Eurostat (AT, BE, ES, …, SE).
#
# - Limpie el valor numérico:
#
#   - Conversión de `Value` (VARCHAR) a `DOUBLE`.
#   - Tratamiento de posibles vacíos / valores especiales como `NULL`.
#
# El resultado se guardará en:
#
# `data_processed/faostat/faostat_cahd_eu27_2017_2023.parquet`

# %%
from pathlib import Path
import duckdb
import pandas as pd

# Carpeta raíz del proyecto
ROOT_DIR = Path("..").resolve().parent

# Carpetas de datos crudos y procesados de FAOSTAT
DATA_RAW = ROOT_DIR / "data_raw" / "faostat"
DATA_PROCESSED = ROOT_DIR / "data_processed" / "faostat"

# Fichero CSV original descargado de FAOSTAT (CoAHD)
FAOSTAT_CSV = DATA_RAW / "FAOSTAT_data_en_12-9-2025.csv"

# Fichero de salida (Parquet limpio, UE-27, 2017–2023)
FAOSTAT_PARQUET = DATA_PROCESSED / "faostat_cahd_eu27_2017_2023.parquet"

ROOT_DIR, FAOSTAT_CSV.exists(), FAOSTAT_CSV, FAOSTAT_PARQUET
# Out:
# (WindowsPath('C:/Users/santi/OneDrive - UNIR/UNIR/MASTER ANÁLISIS Y VISUALIZACIÓN BIG DATA/TFM/dashboard-coherencia-ue-tfm'),
#  True,
#  WindowsPath('C:/Users/santi/OneDrive - UNIR/UNIR/MASTER ANÁLISIS Y VISUALIZACIÓN BIG DATA/TFM/dashboard-coherencia-ue-tfm/data_raw/faostat/FAOSTAT_data_en_12-9-2025.csv'),
#  WindowsPath('C:/Users/santi/OneDrive - UNIR/UNIR/MASTER ANÁLISIS Y VISUALIZACIÓN BIG DATA/TFM/dashboard-coherencia-ue-tfm/data_processed/faostat/faostat_cahd_eu27_2017_2023.parquet'))

# %%
# Conexión en memoria a DuckDB
con = duckdb.connect(database=":memory:")

# Vista rápida del CSV de FAOSTAT
preview = con.execute(f"""
    SELECT *
    FROM read_csv_auto('{FAOSTAT_CSV}', header=TRUE)
    LIMIT 5
""").fetchdf()

preview
# Out:
#   Domain Code                                            Domain  \
# 0        CAHD  Cost and Affordability of a Healthy Diet (CoAHD)
# 1        CAHD  Cost and Affordability of a Healthy Diet (CoAHD)
# 2        CAHD  Cost and Affordability of a Healthy Diet (CoAHD)
# 3        CAHD  Cost and Affordability of a Healthy Diet (CoAHD)
# 4        CAHD  Cost and Affordability of a Healthy Diet (CoAHD)
#
#   Area Code (M49)     Area  Element Code Element  Item Code  \
# 0             040  Austria          6205   Value      70041
# 1             040  Austria          6205   Value      70041
# 2             040  Austria          6205   Value      70041
# 3             040  Austria          6205   Value      70041
# 4             040  Austria          6205   Value      70041
#
#                                                 Item  Year Code  Year  \
# 0  Cost of a healthy diet (CoHD), LCU per person ...       2017  2017
# 1  Cost of a healthy diet (CoHD), LCU per person ...       2018  2018
# 2  Cost of a healthy diet (CoHD), LCU per person ...       2019  2019
# 3  Cost of a healthy diet (CoHD), LCU per person ...       2020  2020
# 4  Cost of a healthy diet (CoHD), LCU per person ...       2021  2021
#
#                    Release       Unit Value Flag Flag Description
# 0  July 2025 (SOFI report)  LCU/cap/d  1.72    E  Estimated value
# 1  July 2025 (SOFI report)  LCU/cap/d  1.75    E  Estimated value
# 2  July 2025 (SOFI report)  LCU/cap/d  1.77    E  Estimated value
# 3  July 2025 (SOFI report)  LCU/cap/d  1.81    E  Estimated value
# 4  July 2025 (SOFI report)  LCU/cap/d  1.82    E  Estimated value

# %%
# Esquema de columnas del CSV de FAOSTAT
schema_df = con.execute(f"""
    DESCRIBE
    SELECT *
    FROM read_csv_auto('{FAOSTAT_CSV}', header=TRUE)
""").fetchdf()

schema_df
# Out:
#          column_name column_type null   key default extra
# 0        Domain Code     VARCHAR  YES  None    None  None
# 1             Domain     VARCHAR  YES  None    None  None
# 2    Area Code (M49)     VARCHAR  YES  None    None  None
# 3               Area     VARCHAR  YES  None    None  None
# 4       Element Code      BIGINT  YES  None    None  None
# 5            Element     VARCHAR  YES  None    None  None
# 6          Item Code      BIGINT  YES  None    None  None
# 7               Item     VARCHAR  YES  None    None  None
# 8          Year Code      BIGINT  YES  None    None  None
# 9               Year      BIGINT  YES  None    None  None
# 10           Release     VARCHAR  YES  None    None  None
# 11              Unit     VARCHAR  YES  None    None  None
# 12             Value     VARCHAR  YES  None    None  None
# 13              Flag     VARCHAR  YES  None    None  None
# 14  Flag Description     VARCHAR  YES  None    None  None

# %%
# Resumen básico de años, áreas, items y elementos
basic_stats = con.execute(f"""
    SELECT
        MIN("Year") AS min_year,
        MAX("Year") AS max_year,
        COUNT(*)     AS n_filas,
        COUNT(DISTINCT "Area")    AS n_areas,
        COUNT(DISTINCT "Item")    AS n_items,
        COUNT(DISTINCT "Element") AS n_elements
    FROM read_csv_auto('{FAOSTAT_CSV}', header=TRUE)
""").fetchdf()

basic_stats
# Out:
#    min_year  max_year  n_filas  n_areas  n_items  n_elements
# 0      2017      2024     1512       27       16           1

# %%
# Items (indicadores) más frecuentes en el dominio CAHD
items_df = con.execute(f"""
    SELECT "Item", "Unit", COUNT(*) AS n
    FROM read_csv_auto('{FAOSTAT_CSV}', header=TRUE)
    GROUP BY "Item", "Unit"
    ORDER BY n DESC
    LIMIT 20
""").fetchdf()

items_df
# Out:
#                                                  Item  \
# 0        Prevalence of unaffordability (PUA), percent
# 1   Number of people unable to afford a healthy di...
# 2   Cost of a healthy diet (CoHD), PPP dollar per ...
# 3   Cost of a healthy diet (CoHD), LCU per person ...
# 4              Cost of fruits, LCU per person per day
# 5   Cost of oils and fats, PPP dollar per person p...
# 6   Cost of vegetables, PPP dollar per person per day
# 7   Cost of legumes, nuts and seeds, LCU per perso...
# 8   Cost of starchy staples, PPP dollar per person...
# 9   Cost of animal source foods, PPP dollar per pe...
# 10    Cost of starchy staples, LCU per person per day
# 11  Cost of animal source foods, LCU per person pe...
# 12         Cost of vegetables, LCU per person per day
# 13      Cost of fruits, PPP dollar per person per day
# 14      Cost of oils and fats, LCU per person per day
# 15  Cost of legumes, nuts and seeds, PPP dollar pe...
#
#                              Unit    n
# 0                               %  378
# 1                      million No  378
# 2   Int$ (PPP) per person per day  216
# 3                       LCU/cap/d  216
# 4                       LCU/cap/d   27
# 5   Int$ (PPP) per person per day   27
# 6   Int$ (PPP) per person per day   27
# 7                       LCU/cap/d   27
# 8   Int$ (PPP) per person per day   27
# 9   Int$ (PPP) per person per day   27
# 10                      LCU/cap/d   27
# 11                      LCU/cap/d   27
# 12                      LCU/cap/d   27
# 13  Int$ (PPP) per person per day   27
# 14                      LCU/cap/d   27
# 15  Int$ (PPP) per person per day   27

# %%
# Áreas (países) más frecuentes
areas_df = con.execute(f"""
    SELECT "Area", COUNT(*) AS n
    FROM read_csv_auto('{FAOSTAT_CSV}', header=TRUE)
    GROUP BY "Area"
    ORDER BY n DESC
    LIMIT 30
""").fetchdf()

areas_df
# Out:
#                             Area   n
# 0                        Germany  56
# 1                       Slovakia  56
# 2                        Denmark  56
# 3                        Hungary  56
# 4                        Czechia  56
# 5                       Bulgaria  56
# 6                       Portugal  56
# 7                        Romania  56
# 8                         Sweden  56
# 9                      Lithuania  56
# 10                       Finland  56
# 11                         Italy  56
# 12                        Poland  56
# 13  Netherlands (Kingdom of the)  56
# 14                       Belgium  56
# 15                         Spain  56
# 16                        Latvia  56
# 17                       Estonia  56
# 18                       Ireland  56
# 19                    Luxembourg  56
# 20                         Malta  56
# 21                      Slovenia  56
# 22                       Austria  56
# 23                        Greece  56
# 24                        France  56
# 25                       Croatia  56
# 26                        Cyprus  56

# %%
# Cobertura específica del periodo 2017–2023
stats_2017_2023 = con.execute(f"""
    SELECT
        SUM( ("Year" BETWEEN 2017 AND 2023)::INT ) AS n_2017_2023,
        COUNT(*) AS n_total
    FROM read_csv_auto('{FAOSTAT_CSV}', header=TRUE)
""").fetchdf()

# %% [markdown]
# ### Definición de países UE-27 y correspondencia con código ISO2 (Eurostat)
#
# FAOSTAT utiliza nombres de país en inglés (Austria, Belgium, Spain, …), mientras que en Eurostat el código `geo` se expresa como:
#
# - AT, BE, BG, HR, CY, CZ, DK, EE, FI, FR, DE, EL,
# - HU, IE, IT, LV, LT, LU, MT, NL, PL, PT, RO, SK,
# - SI, ES, SE.
#
# En este ETL se construye una correspondencia explícita:
#
# - `Area` (FAOSTAT) → `geo` (código ISO2 estilo Eurostat).
#
# Esto permitirá después cruzar FAOSTAT con HICP, HBS y OFF.

# %%
# Comprobación rápida: lista de áreas distintas en el CSV (para referencia)
all_areas = con.execute(f"""
    SELECT DISTINCT "Area"
    FROM read_csv_auto('{FAOSTAT_CSV}', header=TRUE)
    ORDER BY "Area"
""").fetchdf()

all_areas.head(30)
# Out:
#                             Area
# 0                        Austria
# 1                        Belgium
# 2                       Bulgaria
# 3                        Croatia
# 4                         Cyprus
# 5                        Czechia
# 6                        Denmark
# 7                        Estonia
# 8                        Finland
# 9                         France
# 10                       Germany
# 11                        Greece
# 12                       Hungary
# 13                       Ireland
# 14                         Italy
# 15                        Latvia
# 16                     Lithuania
# 17                    Luxembourg
# 18                         Malta
# 19  Netherlands (Kingdom of the)
# 20                        Poland
# 21                      Portugal
# 22                       Romania
# 23                      Slovakia
# 24                      Slovenia
# 25                         Spain
# 26                        Sweden

# %%
# Aseguramos carpeta de salida para los datos procesados
FAOSTAT_PARQUET.parent.mkdir(parents=True, exist_ok=True)

# ETL principal:
#   - Filtrar dominio CAHD.
#   - Limpiar columna Value -> DOUBLE.
#   - Filtrar UE-27 mediante mapeo Area -> geo (código ISO2).
#   - Limitar a años 2017–2023.
con.execute(f"""
    COPY (
        WITH base AS (
            SELECT
                "Domain Code"        AS domain_code,
                "Domain"             AS domain,
                "Area Code (M49)"    AS area_m49,
                "Area"               AS area,
                "Element Code"       AS element_code,
                "Element"            AS element,
                "Item Code"          AS item_code,
                "Item"               AS item,
                "Year"               AS year,
                "Unit"               AS unit,
                "Value"              AS value_raw,
                "Flag"               AS flag,
                "Flag Description"   AS flag_desc
            FROM read_csv_auto('{FAOSTAT_CSV}', header=TRUE)
            WHERE "Domain Code" = 'CAHD'
        ),
        clean AS (
            SELECT
                domain_code,
                domain,
                area_m49,
                area,
                element_code,
                element,
                item_code,
                item,
                CAST(year AS INTEGER) AS year,
                unit,
                -- Limpieza de Value:
                --   - TRIM para quitar espacios.
                --   - Eliminamos el símbolo '<' (p.ej. '<0.1' -> '0.1').
                --   - '' y '..' -> NULL.
                --   - conversión a DOUBLE.
                NULLIF(
                    NULLIF(
                        REPLACE(TRIM(value_raw), '<', ''),
                        ''
                    ),
                    '..'
                )::DOUBLE AS value,
                flag,
                flag_desc
            FROM base
        ),
        eu27 AS (
            SELECT
                c.domain_code,
                c.domain,
                c.area_m49,
                c.area,
                m.iso2 AS geo,   -- código ISO2 compatible con Eurostat
                c.element_code,
                c.element,
                c.item_code,
                c.item,
                c.year,
                c.unit,
                c.value,
                c.flag,
                c.flag_desc
            FROM clean c
            JOIN (
                VALUES
                    ('Austria',                             'AT'),
                    ('Belgium',                             'BE'),
                    ('Bulgaria',                            'BG'),
                    ('Croatia',                             'HR'),
                    ('Cyprus',                              'CY'),
                    ('Czechia',                             'CZ'),
                    ('Denmark',                             'DK'),
                    ('Estonia',                             'EE'),
                    ('Finland',                             'FI'),
                    ('France',                              'FR'),
                    ('Germany',                             'DE'),
                    ('Greece',                              'EL'),
                    ('Hungary',                             'HU'),
                    ('Ireland',                             'IE'),
                    ('Italy',                               'IT'),
                    ('Latvia',                              'LV'),
                    ('Lithuania',                           'LT'),
                    ('Luxembourg',                          'LU'),
                    ('Malta',                               'MT'),
                    ('Netherlands (Kingdom of the)',        'NL'),
                    ('Poland',                              'PL'),
                    ('Portugal',                            'PT'),
                    ('Romania',                             'RO'),
                    ('Slovakia',                            'SK'),
                    ('Slovenia',                            'SI'),
                    ('Spain',                               'ES'),
                    ('Sweden',                              'SE')
            ) AS m(area, iso2)
              ON c.area = m.area
            WHERE c.year BETWEEN 2017 AND 2023
        )
        SELECT
            domain_code,
            domain,
            area_m49,
            area,
            geo,
            element_code,
            element,
            item_code,
            item,
            year,
            unit,
            value,
            flag,
            flag_desc
        FROM eu27
    )
    TO '{FAOSTAT_PARQUET}'
    (FORMAT PARQUET)
""")

FAOSTAT_PARQUET.exists(), FAOSTAT_PARQUET
# Out:
# (True,
#  WindowsPath('C:/Users/santi/OneDrive - UNIR/UNIR/MASTER ANÁLISIS Y VISUALIZACIÓN BIG DATA/TFM/dashboard-coherencia-ue-tfm/data_processed/faostat/faostat_cahd_eu27_2017_2023.parquet'))

# %%
# Muestra de control del Parquet resultante
faostat_sample = con.execute(f"""
    SELECT
        geo,
        area,
        year,
        item,
        unit,
        value,
        flag
    FROM read_parquet('{FAOSTAT_PARQUET}')
    ORDER BY geo, item, year
    LIMIT 20
""").fetchdf()

faostat_sample
# Out:
#    geo     area  year                                               item  \
# 0   AT  Austria  2017  Cost of a healthy diet (CoHD), LCU per person ...
# 1   AT  Austria  2018  Cost of a healthy diet (CoHD), LCU per person ...
# 2   AT  Austria  2019  Cost of a healthy diet (CoHD), LCU per person ...
# 3   AT  Austria  2020  Cost of a healthy diet (CoHD), LCU per person ...
# 4   AT  Austria  2021  Cost of a healthy diet (CoHD), LCU per person ...
# 5   AT  Austria  2022  Cost of a healthy diet (CoHD), LCU per person ...
# 6   AT  Austria  2023  Cost of a healthy diet (CoHD), LCU per person ...
# 7   AT  Austria  2017  Cost of a healthy diet (CoHD), PPP dollar per ...
# 8   AT  Austria  2018  Cost of a healthy diet (CoHD), PPP dollar per ...
# 9   AT  Austria  2019  Cost of a healthy diet (CoHD), PPP dollar per ...
# 10  AT  Austria  2020  Cost of a healthy diet (CoHD), PPP dollar per ...
# 11  AT  Austria  2021  Cost of a healthy diet (CoHD), PPP dollar per ...
# 12  AT  Austria  2022  Cost of a healthy diet (CoHD), PPP dollar per ...
# 13  AT  Austria  2023  Cost of a healthy diet (CoHD), PPP dollar per ...
# 14  AT  Austria  2021  Cost of animal source foods, LCU per person pe...
# 15  AT  Austria  2021  Cost of animal source foods, PPP dollar per pe...
# 16  AT  Austria  2021             Cost of fruits, LCU per person per day
# 17  AT  Austria  2021      Cost of fruits, PPP dollar per person per day
# 18  AT  Austria  2021  Cost of legumes, nuts and seeds, LCU per perso...
# 19  AT  Austria  2021  Cost of legumes, nuts and seeds, PPP dollar pe...
#
#                              unit  value flag
# 0                       LCU/cap/d   1.72    E
# 1                       LCU/cap/d   1.75    E
# 2                       LCU/cap/d   1.77    E
# 3                       LCU/cap/d   1.81    E
# 4                       LCU/cap/d   1.82    E
# 5                       LCU/cap/d   2.02    E
# 6                       LCU/cap/d   2.24    E
# 7   Int$ (PPP) per person per day   2.06    E
# 8   Int$ (PPP) per person per day   2.11    E
# 9   Int$ (PPP) per person per day   2.19    E
# 10  Int$ (PPP) per person per day   2.30    E
# 11  Int$ (PPP) per person per day   2.42    E
# 12  Int$ (PPP) per person per day   2.75    E
# 13  Int$ (PPP) per person per day   2.91    E
# 14                      LCU/cap/d   0.41    E
# 15  Int$ (PPP) per person per day   0.55    E
# 16                      LCU/cap/d   0.54    E
# 17  Int$ (PPP) per person per day   0.72    E
# 18                      LCU/cap/d   0.08    E
# 19  Int$ (PPP) per person per day   0.10    E

# %%
# Resumen del dataset procesado: rango de años, nº filas, países, items
faostat_stats = con.execute(f"""
    SELECT
        MIN(year)               AS min_year,
        MAX(year)               AS max_year,
        COUNT(*)                AS n_filas,
        COUNT(DISTINCT geo)     AS n_paises,
        COUNT(DISTINCT item)    AS n_items,
        COUNT(DISTINCT unit)    AS n_units
    FROM read_parquet('{FAOSTAT_PARQUET}')
""").fetchdf()

faostat_stats
# Out:
#    min_year  max_year  n_filas  n_paises  n_items  n_units
# 0      2017      2023     1404        27       16        4

# %%
# Esquema del Parquet de salida
faostat_schema_out = con.execute(f"""
    DESCRIBE
    SELECT *
    FROM read_parquet('{FAOSTAT_PARQUET}')
""").fetchdf()

faostat_schema_out
# Out:
#      column_name column_type null   key default extra
# 0    domain_code     VARCHAR  YES  None    None  None
# 1         domain     VARCHAR  YES  None    None  None
# 2       area_m49     VARCHAR  YES  None    None  None
# 3           area     VARCHAR  YES  None    None  None
# 4            geo     VARCHAR  YES  None    None  None
# 5   element_code      BIGINT  YES  None    None  None
# 6        element     VARCHAR  YES  None    None  None
# 7      item_code      BIGINT  YES  None    None  None
# 8           item     VARCHAR  YES  None    None  None
# 9           year     INTEGER  YES  None    None  None
# 10          unit     VARCHAR  YES  None    None  None
# 11         value      DOUBLE  YES  None    None  None
# 12          flag     VARCHAR  YES  None    None  None
# 13     flag_desc     VARCHAR  YES  None    None  None
